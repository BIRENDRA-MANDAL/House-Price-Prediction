# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Datasets

# %%
df_train=pd.read_csv("train.csv")
df_test=pd.read_csv("test.csv")

print("Shape of df_train: ",df_train.shape)
print("Shape of df_test: ",df_test.shape)
# Out:
# Shape of df_train:  (1460, 81)
# Shape of df_test:  (1459, 80)

# %%
#to show all rows and columns
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Combining Dataset for PreProcessing

# %%
df=pd.concat([df_train,df_test])
print("Shape of Combined dataframe: ",df.shape)
# Out:
# Shape of Combined dataframe:  (2919, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # OBSERVATION- WE SAW THAT TRAIN DATA HAD 81 ROWS AND TEST DATA HAD 80 ROWS.SO,NOW AFTER WE COMBINE BOTH THE DATASET WE SEE THAT LAST COLUMN OF TEST DATA HAS BEEN FILLED BY NaN VALUE.

# %% [markdown]
# # Get brief Information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [markdown]
# # Extracting Datatype Of Features

# %%
int_features=df.select_dtypes(include=["int64"]).columns
print("Total no of integer features: ",int_features.shape[0])
print("Integer feature names: ",int_features)
print("Integer feature names: ",int_features.tolist())
# Out:
# Total no of integer features:  26
# Integer feature names:  Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')
# Integer feature names:  ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
float_features=df.select_dtypes(include=["float64"]).columns
print("Total no of float features: ",float_features.shape[0])
print("Float feature names: ",float_features)
print("Gloat feature names: ",float_features.tolist())
# Out:
# Total no of float features:  12
# Float feature names:  Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'SalePrice'],
#       dtype='object')
# Gloat feature names:  ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'SalePrice']

# %%
cat_features=df.select_dtypes(include=["object"]).columns
print("Total no of categorial features: ",cat_features.shape[0])
print("Categorical feature names: ",cat_features)
print("Categorical feature names: ",cat_features.tolist())
# Out:
# Total no of categorial features:  43
# Categorical feature names:  Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')
# ...

# %% [markdown]
# # Total no of Numeric features=26+12=38
# # Statical Information of Numeric features

# %%
df.describe() ##in count NaN values are not taken into account
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
df.describe().shape
# Out:
# (8, 38)

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# # Finding missing values

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull())
##isnull convert the dataframe to 0 and 1 where Null values are 1 and Non-Null values are 0
# Out:
# <Axes: >

# %%
#set index as ID column
df=df.set_index("Id")

null_count=df.isnull().sum()
null_count
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
null_percent=(df.isnull().sum()/df.shape[0])*100
null_percent
# Out:
# MSSubClass        0.000000
# MSZoning          0.137033
# LotFrontage      16.649538
# LotArea           0.000000
# Street            0.000000
# Alley            93.216855
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.068517
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.034258
# Exterior2nd       0.034258
# MasVnrType        0.822199
# MasVnrArea        0.787941
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.774923
# BsmtCond          2.809181
# BsmtExposure      2.809181
# BsmtFinType1      2.706406
# BsmtFinSF1        0.034258
# ...

# %% [markdown]
# ## DROP COLUMNS OR FEATURES

# %%
missing_value_50_percent=null_percent[null_percent>50]
missing_value_50_percent
# Out:
# Alley          93.216855
# PoolQC         99.657417
# Fence          80.438506
# MiscFeature    96.402878
# dtype: float64

# %%
df["Alley"].value_counts()  ## Excludes NaN values by default.
# Out:
# Grvl    120
# Pave     78
# Name: Alley, dtype: int64

# %% [markdown]
# # We see that NaN values are not taken into account.So,it considers missing values>90% .But,actually there is value .We have to replace NaN by NA according to domain knowledge.

# %%
missing_value_50_20_percent=null_percent[(null_percent>20)&(null_percent<51)]
missing_value_50_20_percent
# Out:
# FireplaceQu    48.646797
# SalePrice      49.982871
# dtype: float64

# %%
missing_value_5_20_percent=null_percent[(null_percent>5)&(null_percent<21)]
missing_value_5_20_percent
# Out:
# LotFrontage     16.649538
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# dtype: float64

# %%
df["LotFrontage"].value_counts().head()
# Out:
# 60.0    276
# 80.0    137
# 70.0    133
# 50.0    117
# 75.0    105
# Name: LotFrontage, dtype: int64

# %%
sns.heatmap(df[missing_value_5_20_percent.keys()].isnull())
# Out:
# <Axes: ylabel='Id'>

# %% [markdown]
# # OBSERVATION- HEATMAP SHOWS A PATTERN FOR MISSING VALUES OF GARAGE FEATURES.SO,NO FEATURES CAN BE DROPPED.

# %% [markdown]
# ## MISSING VALUE IMPUTATION

# %%
missing_value_feature=null_percent[null_percent>0]
print(missing_value_feature)
print("Total no.of missing values features: ",len(missing_value_feature))
# Out:
# MSZoning         0.137033
# LotFrontage     16.649538
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType       0.822199
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# SalePrice       49.982871
# dtype: float64
# ...

# %%
cat_missing_features=missing_value_feature[missing_value_feature.keys().isin(cat_features)]
print("Total no of categorical missing features: ",len(cat_missing_features))
cat_missing_features
# Out:
# Total no of categorical missing features:  23
# MSZoning         0.137033
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType       0.822199
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
# Electrical       0.034258
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# dtype: float64

# %%
int_missing_features=missing_value_feature[missing_value_feature.keys().isin(int_features)]
print("Total no of integer missing features: ",len(int_missing_features))
int_missing_features
# Out:
# Total no of integer missing features:  0
# Series([], dtype: float64)

# %%
float_missing_features=missing_value_feature[missing_value_feature.keys().isin(float_features)]
print("Total no of float missing features: ",len(float_missing_features))
float_missing_features
# Out:
# Total no of float missing features:  12
# LotFrontage     16.649538
# MasVnrArea       0.787941
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# GarageYrBlt      5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# SalePrice       49.982871
# dtype: float64

# %% [markdown]
# # Total no of Float missing feature is 11 as SalePrice is not a missing feature

# %% [markdown]
# ## Handling MSZoning  0.137033

# %%
df["MSZoning"].value_counts()
# Out:
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: MSZoning, dtype: int64

# %% [markdown]
# # FOR CATEGORICAL DATA ,USE MODE
#
# # FOR NUMERICAL DATA
#
#
# # WHEN THE CURVE IS BELL SHAPED,USE MEAN FOR IMPUTING MISSING VALUE
# # WHEN THE CURVE IS SKEWED, WE CAN'T USE MEAN AS IT IS BIASED TOWARDS OUTLIERS (i.e TOWARDS LEFT OR RIGHT ACCORDING TO SKWENESS),SO WE USE MEDIAN FOR MISSING VALUE IMPUTATION

# %%
sns.countplot(data=df,x="MSZoning")
plt.show()

# %%
MSZoning_mode=df["MSZoning"].mode()[0]
MSZoning_mode
# Out:
# 'RL'

# %%
##creating backup of original data
df_miss_impu=df.copy()
df_miss_impu.shape
# Out:
# (2919, 80)

# %% [markdown]
# # We see here are 80 features instead of 81 as ID coulmn was set index earlier

# %%
df_miss_impu["MSZoning"].replace(np.nan,MSZoning_mode,inplace=True)
df_miss_impu["MSZoning"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="MSZoning")
plt.show()

# %% [markdown]
# ## Handling Alley 93.216855

# %%
df_miss_impu["Alley"].value_counts()
# Out:
# Grvl    120
# Pave     78
# Name: Alley, dtype: int64

# %%
Alley_count="NA" ##replace NaN with a string NA
df_miss_impu["Alley"].replace(np.nan,Alley_count,inplace=True)
df_miss_impu["Alley"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df,x="Alley")
plt.show()

# %%
sns.countplot(data=df_miss_impu,x="Alley")
plt.show()

# %% [markdown]
# ## Handling LotFrontage 16.649538

# %%
df["LotFrontage"].value_counts()
# Out:
# 60.0     276
# 80.0     137
# 70.0     133
# 50.0     117
# 75.0     105
# 65.0      93
# 85.0      76
# 21.0      50
# 24.0      49
# 63.0      47
# 90.0      46
# 78.0      46
# 68.0      44
# 64.0      43
# 74.0      39
# 72.0      39
# 73.0      33
# 62.0      31
# 79.0      28
# 100.0     28
# 82.0      28
# 52.0      28
# 51.0      27
# 59.0      27
# 57.0      26
# 66.0      26
# 76.0      25
# 55.0      24
# 53.0      24
# 43.0      23
# 88.0      22
# 67.0      22
# 69.0      20
# 35.0      19
# 71.0      19
# 56.0      19
# 44.0      19
# 84.0      18
# 81.0      18
# 58.0      17
# 61.0      17
# 48.0      16
# 40.0      16
# 34.0      16
# 86.0      15
# 92.0      15
# 95.0      15
# 110.0     15
# 77.0      15
# 41.0      14
# 120.0     14
# 91.0      14
# 96.0      14
# 83.0      13
# 93.0      13
# 94.0      12
# 42.0      12
# 105.0     12
# 98.0      12
# 87.0      11
# 107.0     11
# 30.0      11
# 54.0      10
# 45.0      10
# 89.0      10
# 102.0     10
# ...

# %%
sns.boxplot(data=df,x="LotFrontage")
# Out:
# <Axes: xlabel='LotFrontage'>

# %%
sns.displot(df["LotFrontage"])

# %% [markdown]
# ## WE SEE IT IS RIGHT SKEWED . SO,WE USE MEDIAN VALUE NOT MEAN VALUE FOR MISSING VALUE IMPUTATION

# %%
LotFrontage_median=df["LotFrontage"].median()
LotFrontage_median
# Out:
# 68.0

# %%
df_miss_impu["LotFrontage"].replace(np.nan,LotFrontage_median,inplace=True)
df_miss_impu["LotFrontage"].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(data=df_miss_impu,x="LotFrontage")
# Out:
# <Axes: xlabel='LotFrontage'>

# %%
sns.displot(df_miss_impu["LotFrontage"])

# %% [markdown]
# # median-increased,outliers-increased

# %% [markdown]
# ## Handling Utilities 0.068517

# %%
df["Utilities"].value_counts()
# Out:
# AllPub    2916
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
Utilities_mode=df["Utilities"].mode()[0]
Utilities_mode
# Out:
# 'AllPub'

# %%
df_miss_impu["Utilities"].replace(np.nan,Utilities_mode,inplace=True)
df_miss_impu["Utilities"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df,x="Utilities")
plt.show()

# %%
sns.countplot(data=df_miss_impu,x="Utilities")
plt.show()

# %% [markdown]
# ## Handling Exterior1st 0.034258 AND Exterior2nd 0.034258

# %%
df["Exterior1st"].value_counts()
# Out:
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# Stone         2
# CBlock        2
# ImStucc       1
# Name: Exterior1st, dtype: int64

# %%
df["Exterior2nd"].value_counts()
# Out:
# VinylSd    1014
# MetalSd     447
# HdBoard     406
# Wd Sdng     391
# Plywood     270
# CmentBd     126
# Wd Shng      81
# BrkFace      47
# Stucco       47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# Name: Exterior2nd, dtype: int64

# %%
Exterior1st_mode=df["Exterior1st"].mode()[0]
df_miss_impu["Exterior1st"].replace(np.nan,Exterior1st_mode,inplace=True)
df_miss_impu["Exterior1st"].isnull().sum()
# Out:
# 0

# %%
Exterior2nd_mode=df["Exterior2nd"].mode()[0]
df_miss_impu["Exterior2nd"].replace(np.nan,Exterior2nd_mode,inplace=True)
df_miss_impu["Exterior2nd"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df,x="Exterior1st")
plt.show()

# %%
sns.countplot(data=df_miss_impu,x="Exterior1st")
plt.show()

# %%
sns.countplot(data=df,x="Exterior2nd")
plt.show()

# %%
sns.countplot(data=df_miss_impu,x="Exterior2nd")
plt.show()

# %% [markdown]
# ## Handling MasVnrType 0.822199 AND MasVnrArea 0.787941

# %%
sns.heatmap(df[["MasVnrType","MasVnrArea"]].isnull())
# Out:
# <Axes: ylabel='Id'>

# %% [markdown]
# # Heatmap shows a pattern for these 2 features

# %%
df["MasVnrType"].value_counts()
# Out:
# None       1742
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: MasVnrType, dtype: int64

# %%
df["MasVnrArea"].value_counts()
# Out:
# 0.0       1738
# 120.0       15
# 176.0       13
# 200.0       13
# 216.0       12
# 180.0       12
# 72.0        11
# 16.0        11
# 144.0       11
# 108.0       11
# 340.0       10
# 196.0        9
# 210.0        9
# 128.0        9
# 80.0         9
# 170.0        8
# 132.0        8
# 302.0        8
# 40.0         8
# 256.0        8
# 178.0        8
# 76.0         7
# 203.0        7
# 270.0        7
# 44.0         7
# 174.0        7
# 60.0         7
# 260.0        7
# 320.0        7
# 50.0         7
# 252.0        7
# 106.0        7
# 84.0         7
# 300.0        7
# 140.0        7
# 164.0        7
# 186.0        7
# 240.0        7
# 456.0        7
# 360.0        7
# 420.0        7
# 90.0         6
# 232.0        6
# 112.0        6
# 246.0        6
# 145.0        6
# 143.0        6
# 504.0        6
# 198.0        6
# 130.0        6
# 306.0        6
# 288.0        6
# 168.0        5
# 268.0        5
# 148.0        5
# 513.0        5
# 160.0        5
# 98.0         5
# ...

# %%
MasVnrArea_const=0 ##missing values are replaced with 0 as none is the maximum occuring value in other feature
df_miss_impu["MasVnrArea"].replace(np.nan,MasVnrArea_const,inplace=True)
df_miss_impu["MasVnrArea"].isnull().sum()
# Out:
# 0

# %%
MasVnrType_mode=df["MasVnrType"].mode()[0]
df_miss_impu["MasVnrType"].replace(np.nan,MasVnrType_mode,inplace=True)
df_miss_impu["MasVnrType"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df,x="MasVnrType")
plt.show()

# %%
sns.countplot(data=df_miss_impu,x="MasVnrType")
plt.show()

# %%
sns.boxplot(data=df_miss_impu,x="MasVnrArea")
# Out:
# <Axes: xlabel='MasVnrArea'>

# %%
sns.displot(df_miss_impu["MasVnrArea"])

# %% [markdown]
# # Handling Basement Features

# %%
cat_bsmt_feat=["BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinType2"]
num_bsmt_feat=["BsmtFinSF1","BsmtFinSF2","BsmtUnfSF","TotalBsmtSF","BsmtFullBath","BsmtHalfBath"]

# %%
sns.heatmap(df[cat_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
df["BsmtQual"].value_counts()
# Out:
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: BsmtQual, dtype: int64

# %%
df["BsmtCond"].value_counts()
# Out:
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: BsmtCond, dtype: int64

# %%
df["BsmtExposure"].value_counts()
# Out:
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: BsmtExposure, dtype: int64

# %%
df["BsmtFinType1"].value_counts()
# Out:
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: BsmtFinType1, dtype: int64

# %%
df["BsmtFinType2"].value_counts()
# Out:
# Unf    2493
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64

# %%
Bsmt_cat_const="NA" ##replace with a string NA
df_miss_impu["BsmtQual"].replace(np.nan,Bsmt_cat_const,inplace=True)
df_miss_impu["BsmtQual"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtCond"].replace(np.nan,Bsmt_cat_const,inplace=True)
df_miss_impu["BsmtCond"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtExposure"].replace(np.nan,Bsmt_cat_const,inplace=True)
df_miss_impu["BsmtExposure"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtFinType1"].replace(np.nan,Bsmt_cat_const,inplace=True)
df_miss_impu["BsmtFinType1"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtFinType2"].replace(np.nan,Bsmt_cat_const,inplace=True)
df_miss_impu["BsmtFinType2"].isnull().sum()
# Out:
# 0

# %%
sns.heatmap(df[num_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
df["BsmtFinSF1"].value_counts().head()
# Out:
# 0.0      929
# 24.0      27
# 16.0      14
# 300.0      9
# 288.0      8
# Name: BsmtFinSF1, dtype: int64

# %%
df["BsmtFinSF2"].value_counts().head()
# Out:
# 0.0      2571
# 180.0       5
# 294.0       5
# 435.0       3
# 483.0       3
# Name: BsmtFinSF2, dtype: int64

# %%
df["BsmtUnfSF"].value_counts().head()
# Out:
# 0.0      241
# 384.0     19
# 728.0     14
# 672.0     13
# 600.0     12
# Name: BsmtUnfSF, dtype: int64

# %%
df["TotalBsmtSF"].value_counts().head()
# Out:
# 0.0       78
# 864.0     74
# 672.0     29
# 912.0     26
# 1040.0    25
# Name: TotalBsmtSF, dtype: int64

# %%
df["BsmtFullBath"].value_counts()
# Out:
# 0.0    1705
# 1.0    1172
# 2.0      38
# 3.0       2
# Name: BsmtFullBath, dtype: int64

# %%
df["BsmtHalfBath"].value_counts()
# Out:
# 0.0    2742
# 1.0     171
# 2.0       4
# Name: BsmtHalfBath, dtype: int64

# %%
Bsmt_num_const=0 ##replace with a numeric value 0
df_miss_impu["BsmtFinSF1"].replace(np.nan,Bsmt_num_const,inplace=True)
df_miss_impu["BsmtFinSF1"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtFinSF2"].replace(np.nan,Bsmt_num_const,inplace=True)
df_miss_impu["BsmtFinSF2"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtUnfSF"].replace(np.nan,Bsmt_num_const,inplace=True)
df_miss_impu["BsmtUnfSF"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["TotalBsmtSF"].replace(np.nan,Bsmt_num_const,inplace=True)
df_miss_impu["TotalBsmtSF"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtFullBath"].replace(np.nan,Bsmt_num_const,inplace=True)
df_miss_impu["BsmtFullBath"].isnull().sum()
# Out:
# 0

# %%
df_miss_impu["BsmtHalfBath"].replace(np.nan,Bsmt_num_const,inplace=True)
df_miss_impu["BsmtHalfBath"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Handling Electrical 0.034258 AND KitchenQual 0.034258

# %%
df["Electrical"].value_counts()
# Out:
# SBrkr    2671
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64

# %%
df["KitchenQual"].value_counts()
# Out:
# TA    1492
# Gd    1151
# Ex     205
# Fa      70
# Name: KitchenQual, dtype: int64

# %%
sns.countplot(data=df,x="Electrical")
plt.show()

# %%
Electrical_mode=df["Electrical"].mode()[0]
df_miss_impu["Electrical"].replace(np.nan,Electrical_mode,inplace=True)
df_miss_impu["Electrical"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="Electrical")
plt.show()

# %%
sns.countplot(data=df,x="KitchenQual")
plt.show()

# %%
KitchenQual_mode=df["KitchenQual"].mode()[0]
df_miss_impu["KitchenQual"].replace(np.nan,Electrical_mode,inplace=True)
df_miss_impu["KitchenQual"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="KitchenQual")
plt.show()

# %% [markdown]
# # Handling Functional 0.068517

# %%
df["Functional"].value_counts()
# Out:
# Typ     2717
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: Functional, dtype: int64

# %%
Functional_mode=df["Functional"].mode()[0]
Functional_mode
# Out:
# 'Typ'

# %%
df_miss_impu["Functional"].replace(np.nan,Electrical_mode,inplace=True)
df_miss_impu["Functional"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="Functional")
plt.show()

# %% [markdown]
# # Handling SaleType 0.034258

# %%
df["SaleType"].value_counts()
# Out:
# WD       2525
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# Name: SaleType, dtype: int64

# %%
SaleType_mode=df["SaleType"].mode()[0]
SaleType_mode
# Out:
# 'WD'

# %%
df_miss_impu["SaleType"].replace(np.nan,SaleType_mode,inplace=True)
df_miss_impu["SaleType"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="SaleType")
plt.show()

# %% [markdown]
# # Handling FireplaceQu 48.646797

# %%
df["FireplaceQu"].value_counts()
# Out:
# Gd    744
# TA    592
# Fa     74
# Po     46
# Ex     43
# Name: FireplaceQu, dtype: int64

# %%
FireplaceQu_const="NA" ## NaN is replaced by NA
df_miss_impu["FireplaceQu"].replace(np.nan,FireplaceQu_const,inplace=True)
df_miss_impu["FireplaceQu"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="FireplaceQu")
plt.show()

# %% [markdown]
# # Handling PoolQC 99.657417

# %%
df["PoolQC"].value_counts()
# Out:
# Ex    4
# Gd    4
# Fa    2
# Name: PoolQC, dtype: int64

# %%
PoolQC_const="NA" ## NaN is replaced by NA
df_miss_impu["PoolQC"].replace(np.nan,PoolQC_const,inplace=True)
df_miss_impu["PoolQC"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="PoolQC")
plt.show()

# %% [markdown]
# # Handling Fence 80.438506

# %%
df["Fence"].value_counts()
# Out:
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: Fence, dtype: int64

# %%
Fence_const="NA" ## NaN is replaced by NA
df_miss_impu["Fence"].replace(np.nan,Fence_const,inplace=True)
df_miss_impu["Fence"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="Fence")
plt.show()

# %% [markdown]
# # Handling MiscFeature 96.402878

# %%
df["MiscFeature"].value_counts()
# Out:
# Shed    95
# Gar2     5
# Othr     4
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
MiscFeature_const="NA"
df_miss_impu["MiscFeature"].replace(np.nan,MiscFeature_const,inplace=True)
df_miss_impu["MiscFeature"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="MiscFeature")
plt.show()

# %% [markdown]
# # Handling Garage Features

# %%
cat_garage_feat=["GarageType","GarageFinish","GarageQual","GarageCond"]
num_garage_feat=["GarageYrBlt","GarageCars","GarageArea"]

# %%
cat_garage_const="NA"
df_miss_impu["GarageType"].replace(np.nan,cat_garage_const,inplace=True)
df_miss_impu["GarageType"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="GarageType")
plt.show()

# %%
df_miss_impu["GarageFinish"].replace(np.nan,cat_garage_const,inplace=True)
df_miss_impu["GarageFinish"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="GarageFinish")
plt.show()

# %%
df_miss_impu["GarageQual"].replace(np.nan,cat_garage_const,inplace=True)
df_miss_impu["GarageQual"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="GarageQual")
plt.show()

# %%
df_miss_impu["GarageCond"].replace(np.nan,cat_garage_const,inplace=True)
df_miss_impu["GarageCond"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="GarageCond")
plt.show()

# %%
num_garage_const=0
df_miss_impu["GarageYrBlt"].replace(np.nan,num_garage_const,inplace=True)
df_miss_impu["GarageYrBlt"].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (20,100))
sns.countplot(data=df_miss_impu,y="GarageYrBlt")
plt.show()

# %%
df_miss_impu["GarageCars"].replace(np.nan,num_garage_const,inplace=True)
df_miss_impu["GarageCars"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(data=df_miss_impu,x="GarageCars")
plt.show()

# %%
df_miss_impu["GarageArea"].replace(np.nan,num_garage_const,inplace=True)
df_miss_impu["GarageArea"].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (20,150))
sns.countplot(data=df_miss_impu,y="GarageArea")
plt.show()

# %% [markdown]
# # Feature Transformation

# %% [markdown]
# # Convert Numeric features to Categorial

# %%
df_miss_impu["MSSubClass"].dtype
# Out:
# dtype('int64')

# %%
df_miss_impu["YearBuilt"].dtype
# Out:
# dtype('int64')

# %%
df_miss_impu["YearRemodAdd"].dtype
# Out:
# dtype('int64')

# %%
df_miss_impu["GarageYrBlt"].dtype
# Out:
# dtype('float64')

# %%
df_miss_impu["MoSold"].dtype
# Out:
# dtype('int64')

# %%
df_miss_impu["YrSold"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # convert month number to month

# %%
import calendar

# %%
calendar.month_abbr[12] ##working
# Out:
# 'Dec'

# %%
df_miss_impu["MoSold"]=df_miss_impu["MoSold"].apply( lambda x :calendar.month_abbr[x])

# %%
df_miss_impu["MoSold"].head()
# Out:
# Id
# 1    Feb
# 2    May
# 3    Sep
# 4    Feb
# 5    Dec
# Name: MoSold, dtype: object

# %%
df_miss_impu["MSSubClass"]=df_miss_impu["MSSubClass"].astype(str)
df_miss_impu["YearBuilt"]=df_miss_impu["YearBuilt"].astype(str)
df_miss_impu["YearRemodAdd"]=df_miss_impu["YearRemodAdd"].astype(str)
df_miss_impu["GarageYrBlt"]=df_miss_impu["GarageYrBlt"].astype(str)
df_miss_impu["MoSold"]=df_miss_impu["MoSold"].astype(str)
df_miss_impu["YrSold"]=df_miss_impu["YrSold"].astype(str)

# %%
df_miss_impu["MoSold"].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Convert Categorical to Numeric Feature

# %% [markdown]
# # ordinal format

# %%
from pandas.api.types import CategoricalDtype

# %% [markdown]
# # From Data Description we find the follwing features need to be encoded
# 1.ExterQual
# 2.ExterCond
# 3.BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# HeatingQC
# KitchenQual
# FireplaceQu
# GarageQual
# GarageCond
# PoolQC
# Functional
# GarageFinish
# PavedDrive
# Utilities

# %% [markdown]
# # Encoding ExterQual

# %%
df_miss_impu["ExterQual"].unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
df_miss_impu["ExterQual"].value_counts()
# Out:
# TA    1798
# Gd     979
# Ex     107
# Fa      35
# Name: ExterQual, dtype: int64

# %%
df_miss_impu["ExterQual"]=df_miss_impu["ExterQual"].astype(CategoricalDtype(categories=["Po","Fa","TA","Gd","Ex"],ordered=True)).cat.codes

# %%
df_miss_impu["ExterQual"].value_counts()
# Out:
# 2    1798
# 3     979
# 4     107
# 1      35
# Name: ExterQual, dtype: int64

# %% [markdown]
# # Encoding BsmtExposure

# %%
df_miss_impu["BsmtExposure"].value_counts()
# Out:
# No    1904
# Av     418
# Gd     276
# Mn     239
# NA      82
# Name: BsmtExposure, dtype: int64

# %%
df_miss_impu["BsmtExposure"]=df_miss_impu["BsmtExposure"].astype(CategoricalDtype(categories=["NA","No","Mn","Av","Gd"],ordered=True)).cat.codes

# %%
df_miss_impu["BsmtExposure"].value_counts()
# Out:
# 1    1904
# 3     418
# 4     276
# 2     239
# 0      82
# Name: BsmtExposure, dtype: int64

# %% [markdown]
# # Encoding ExterCond

# %%
df_miss_impu["ExterCond"].value_counts()
# Out:
# TA    2538
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: ExterCond, dtype: int64

# %%
df_miss_impu['ExterCond'] = df_miss_impu['ExterCond'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["ExterCond"].value_counts()
# Out:
# 2    2538
# 3     299
# 1      67
# 4      12
# 0       3
# Name: ExterCond, dtype: int64

# %% [markdown]
# # Encoding BsmtQual

# %%
df_miss_impu["BsmtQual"].value_counts()
# Out:
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# NA      81
# Name: BsmtQual, dtype: int64

# %%
df_miss_impu['BsmtQual'] = df_miss_impu['BsmtQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["BsmtQual"].value_counts()
# Out:
# 3    1283
# 4    1209
# 5     258
# 2      88
# 0      81
# Name: BsmtQual, dtype: int64

# %% [markdown]
# # Encoding BsmtCond

# %%
df_miss_impu["BsmtCond"].value_counts()
# Out:
# TA    2606
# Gd     122
# Fa     104
# NA      82
# Po       5
# Name: BsmtCond, dtype: int64

# %%
df_miss_impu["BsmtCond"] = df_miss_impu["BsmtCond"].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["BsmtCond"].value_counts()
# Out:
# 3    2606
# 4     122
# 2     104
# 0      82
# 1       5
# Name: BsmtCond, dtype: int64

# %% [markdown]
# # Encoding BsmtFinType1

# %%
df_miss_impu["BsmtFinType1"].value_counts()
# Out:
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# NA      79
# Name: BsmtFinType1, dtype: int64

# %%
df_miss_impu['BsmtFinType1'] = df_miss_impu['BsmtFinType1'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes

# %%
df_miss_impu["BsmtFinType1"].value_counts()
# Out:
# 1    851
# 6    849
# 5    429
# 3    288
# 4    269
# 2    154
# 0     79
# Name: BsmtFinType1, dtype: int64

# %% [markdown]
# # Encoding BsmtFinType2

# %%
df_miss_impu["BsmtFinType2"].value_counts()
# Out:
# Unf    2493
# Rec     105
# LwQ      87
# NA       80
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64

# %%
df_miss_impu['BsmtFinType2'] = df_miss_impu['BsmtFinType2'].astype(CategoricalDtype(categories=['NA', 'Unf', 'LwQ', 'Rec', 'BLQ','ALQ', 'GLQ'], ordered = True)).cat.codes

# %%
df_miss_impu["BsmtFinType2"].value_counts()
# Out:
# 1    2493
# 3     105
# 2      87
# 0      80
# 4      68
# 5      52
# 6      34
# Name: BsmtFinType2, dtype: int64

# %% [markdown]
# # Encoding HeatingQC

# %%
df_miss_impu["HeatingQC"].value_counts()
# Out:
# Ex    1493
# TA     857
# Gd     474
# Fa      92
# Po       3
# Name: HeatingQC, dtype: int64

# %%
df_miss_impu['HeatingQC'] = df_miss_impu['HeatingQC'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["HeatingQC"].value_counts()
# Out:
# 4    1493
# 2     857
# 3     474
# 1      92
# 0       3
# Name: HeatingQC, dtype: int64

# %% [markdown]
# # Encoding KitchenQual

# %%
df_miss_impu["KitchenQual"].value_counts()
# Out:
# TA       1492
# Gd       1151
# Ex        205
# Fa         70
# SBrkr       1
# Name: KitchenQual, dtype: int64

# %%
df_miss_impu['KitchenQual'] = df_miss_impu['KitchenQual'].astype(CategoricalDtype(categories=['Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["KitchenQual"].value_counts()
# Out:
#  2    1492
#  3    1151
#  4     205
#  1      70
# -1       1
# Name: KitchenQual, dtype: int64

# %% [markdown]
# # Encoding FireplaceQu

# %%
df_miss_impu["FireplaceQu"].value_counts()
# Out:
# NA    1420
# Gd     744
# TA     592
# Fa      74
# Po      46
# Ex      43
# Name: FireplaceQu, dtype: int64

# %%
df_miss_impu["FireplaceQu"] = df_miss_impu["FireplaceQu"].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["FireplaceQu"].value_counts()
# Out:
# 0    1420
# 4     744
# 3     592
# 2      74
# 1      46
# 5      43
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# # Encoding GarageQual

# %%
df_miss_impu["GarageQual"].value_counts()
# Out:
# TA    2604
# NA     159
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: GarageQual, dtype: int64

# %%
df_miss_impu['GarageQual'] = df_miss_impu['GarageQual'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["GarageQual"].value_counts()
# Out:
# 3    2604
# 0     159
# 2     124
# 4      24
# 1       5
# 5       3
# Name: GarageQual, dtype: int64

# %% [markdown]
# # Encoding GarageCond

# %%
df_miss_impu["GarageCond"].value_counts()
# Out:
# TA    2654
# NA     159
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: GarageCond, dtype: int64

# %%
df_miss_impu['GarageCond'] = df_miss_impu['GarageCond'].astype(CategoricalDtype(categories=['NA', 'Po', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["GarageCond"].value_counts()
# Out:
# 3    2654
# 0     159
# 2      74
# 4      15
# 1      14
# 5       3
# Name: GarageCond, dtype: int64

# %% [markdown]
# # Encoding PoolQC

# %%
df_miss_impu["PoolQC"].value_counts()
# Out:
# NA    2909
# Ex       4
# Gd       4
# Fa       2
# Name: PoolQC, dtype: int64

# %%
df_miss_impu["PoolQC"] = df_miss_impu["PoolQC"].astype(CategoricalDtype(categories=['NA', 'Fa', 'TA', 'Gd', 'Ex'], ordered = True)).cat.codes

# %%
df_miss_impu["PoolQC"].value_counts()
# Out:
# 0    2909
# 4       4
# 3       4
# 1       2
# Name: PoolQC, dtype: int64

# %% [markdown]
# # Encoding Functional

# %%
df_miss_impu["Functional"].value_counts()
# Out:
# Typ      2717
# Min2       70
# Min1       65
# Mod        35
# Maj1       19
# Maj2        9
# Sev         2
# SBrkr       2
# Name: Functional, dtype: int64

# %%
df_miss_impu['Functional'] = df_miss_impu['Functional'].astype(CategoricalDtype(categories=['Sal', 'Sev', 'Maj2', 'Maj1', 'Mod','Min2','Min1', 'Typ'], ordered = True)).cat.codes

# %%
df_miss_impu["Functional"].value_counts()
# Out:
#  7    2717
#  5      70
#  6      65
#  4      35
#  3      19
#  2       9
#  1       2
# -1       2
# Name: Functional, dtype: int64

# %% [markdown]
# # Encoding GarageFinish

# %%
df_miss_impu["GarageFinish"].value_counts()
# Out:
# Unf    1230
# RFn     811
# Fin     719
# NA      159
# Name: GarageFinish, dtype: int64

# %%
df_miss_impu['GarageFinish'] = df_miss_impu['GarageFinish'].astype(CategoricalDtype(categories=['NA', 'Unf', 'RFn', 'Fin'], ordered = True)).cat.codes

# %%
df_miss_impu["GarageFinish"].value_counts()
# Out:
# 1    1230
# 2     811
# 3     719
# 0     159
# Name: GarageFinish, dtype: int64

# %% [markdown]
# # Encoding PavedDrive

# %%
df_miss_impu["PavedDrive"].value_counts()
# Out:
# Y    2641
# N     216
# P      62
# Name: PavedDrive, dtype: int64

# %%
df_miss_impu['PavedDrive'] = df_miss_impu['PavedDrive'].astype(CategoricalDtype(categories=['N', 'P', 'Y'], ordered = True)).cat.codes

# %%
df_miss_impu["PavedDrive"].value_counts()
# Out:
# 2    2641
# 0     216
# 1      62
# Name: PavedDrive, dtype: int64

# %% [markdown]
# # Encoding Utilities

# %%
df_miss_impu["Utilities"].value_counts()
# Out:
# AllPub    2918
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
df_miss_impu['Utilities'] = df_miss_impu['Utilities'].astype(CategoricalDtype(categories=['ELO', 'NoSeWa', 'NoSeWr', 'AllPub'], ordered = True)).cat.codes

# %%
df_miss_impu["Utilities"].value_counts()
# Out:
# 3    2918
# 1       1
# Name: Utilities, dtype: int64

# %%
df_miss_impu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   object
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          2919 non-null   object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   int8
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %% [markdown]
# # One Hot Encoding for Nominal Categorical Data

# %%
df_encod=df_miss_impu.copy()
object_features=df_encod.select_dtypes(include="object").columns.tolist()
print("Total Object Type features = ",len(object_features))
print("Object Features =\n ",object_features)
# Out:
# Total Object Type features =  32
# Object Features =
#   ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', 'GarageYrBlt', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']

# %%
df_encod=pd.get_dummies(df_encod,columns=object_features,prefix=object_features,drop_first=True)

# %%
df_encod.shape
# Out:
# (2919, 513)

# %% [markdown]
# # OBSERVATION- NO.OF COLUMNS HAVE CHANGED

# %%
object_features=df_encod.select_dtypes(include="object").columns.tolist()
print("Total Object Type features = ",len(object_features))
# Out:
# Total Object Type features =  0

# %% [markdown]
# # Split Data For Training & Testing

# %%
len_train=df_train.shape[0]
len_train
# Out:
# 1460

# %%
X_train=df_encod[:len_train].drop("SalePrice",axis=1) # split from first to len_train and drop SalePrice
y_train=df_encod["SalePrice"][:len_train] # get SalePrice column from Train data
X_test=df_encod[len_train:].drop("SalePrice",axis=1) # split from len_train till last and remove SalePrice Column

# %%
X_train.shape
# Out:
# (1460, 512)

# %%
y_train.shape
# Out:
# (1460,)

# %%
X_test.shape
# Out:
# (1459, 512)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(X_train)

X_train=sc.transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# # Training ML Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.isotonic import IsotonicRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

# %%
lr = LinearRegression()
rir = Ridge()
lar = Lasso()
svr = SVR()
knr = KNeighborsRegressor()
gpr = GaussianProcessRegressor()
dtr = DecisionTreeRegressor()
gbr = GradientBoostingRegressor()
rfr = RandomForestRegressor()
xgbr = XGBRegressor()
mlpr = MLPRegressor()

# %%
models= {"a": ["LinearRegression",lr],
         "b": ["Ridge",rir],
         "c": ["Lasso",lar],
         "d": ["SVR",svr],
         "e": ["KNeighborsRegressor",knr],
         "f": ["GaussianProcessRegressor",gpr],
         "g": ["DecisionTreeRegressor",dtr],
         "h": ["GradientBoostingRegressor",gbr],
         "i": ["RandomForestRegressor",rfr],
         "j": ["XGBRegressor",xgbr],
         "k": ["MLPRegressor",mlpr],
        }

# %% [markdown]
# # Getting Test Data using Cross Validation

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import make_scorer, r2_score

def test_model(model, X_train=X_train, y_train=y_train):
    cv = KFold(n_splits = 10, shuffle=True, random_state = 42)
    r2 = make_scorer(r2_score)
    r2_val_score = cross_val_score(model, X_train, y_train, cv=cv, scoring = r2)
    score = [r2_val_score.mean()]
    return score

# %%
for model in models:
    print(models[model][0])
# Out:
# LinearRegression
# Ridge
# Lasso
# SVR
# KNeighborsRegressor
# GaussianProcessRegressor
# DecisionTreeRegressor
# GradientBoostingRegressor
# RandomForestRegressor
# XGBRegressor
# MLPRegressor

# %% [markdown]
# # Getting Score For Each Model

# %%
for model in models:
    print("Training model : ",models[model][0])
    score=test_model(models[model][1], X_train, y_train)
    print("Score of Mode = ",score)
# Out:
# Training model :  LinearRegression
# Score of Mode =  [-7.824311569419202e+25]
# Training model :  Ridge
# Score of Mode =  [0.5489777703820802]
# Training model :  Lasso
# C:\Users\BIRENDRA MANDAL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.216e+10, tolerance: 7.873e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\BIRENDRA MANDAL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.239e+11, tolerance: 8.301e+08
#   model = cd_fast.enet_coordinate_descent(
# ...
